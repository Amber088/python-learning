# %%
import numpy as np
import pandas as pd
country = ['India','Pakistan','SriLanka','England']
s = pd.Series(country)
Num = [1,2,3,4]
a = pd.Series(Num)
print(a)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0       India
# 1    Pakistan
# 2    SriLanka
# 3     England
# dtype: str

# %%
subjects = ['Maths','Science','English','Hindi']
Marks = [100,85,90,70]
pd.Series(Marks,index =subjects)
# Out:
# Maths      100
# Science     85
# English     90
# Hindi       70
# dtype: int64

# %%
marks = pd.Series(Marks,index = subjects,name = "Amber's Marks")
marks
# Out:
# Maths      100
# Science     85
# English     90
# Hindi       70
# Name: Amber's Marks, dtype: int64

# %%
marks = {
    'Hindi':89,
    'English':90,
    'Maths': 100
}
pd.Series(marks)
# Out:
# Hindi       89
# English     90
# Maths      100
# dtype: int64

# %%
pd.read_csv("PANDAS/subs.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pd.read_csv("PANDAS/subs.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
# ...
